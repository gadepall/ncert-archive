# %% [markdown]
# ##### Assignment 5 :

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy import linalg as LA
#Generating points on a circle
def circ_gen(O,r):
	len = 50
	theta = np.linspace(0,2*np.pi,len)
	x_circ = np.zeros((2,len))
	x_circ[0,:] = r*np.cos(theta)
	x_circ[1,:] = r*np.sin(theta)
	x_circ = (x_circ.T + O).T
	return x_circ

# %%
#Input parameters
U_1 = -2*np.array(([1,0])) #cenre
U_2= 2*np.array(([1,0]))
P = np.array(([2,3]))
#Q = np.array(([3,4]))
f = -21
r_1 = np.sqrt(LA.norm(U_1)**2-f) #radius
r_2 = np.sqrt(LA.norm(U_2)**2-f)
x_circ1= circ_gen(U_1,r) #centre(2,0)
x_circ2=circ_gen(U_2,r) #centre(-2,0)

# %%
x1 = [2]
y1 = [3]
c1=[-2]
c2=[0]
plt.plot(x_circ1[0,:],x_circ1[1,:],label='$circle with centre(-2,0)$')
plt.plot(x_circ2[0,:],x_circ2[1,:],label='$circle with centre(2,0)$')
x,=plt.plot(x1, y1,marker='o',color='red',label='Point (2,3)')
c,=plt.plot(c1, c2,marker='o',color='black',label='Centre (-2,0)')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.legend(bbox_to_anchor=(0.8, 1), loc='lower center')
plt.grid() # minor
plt.axis('equal')
plt.show()
